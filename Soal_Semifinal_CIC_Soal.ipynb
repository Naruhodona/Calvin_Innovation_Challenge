# %% [markdown]
# # 1. Import Libraries yang dibutuhkan (0 Poin)

# %%
# Terdapat total 3 import yang anda butuhkan
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Seaborn Setup (0 Poin)

# %%
# Setup seaborn sedemikian rupa sehingga panjang grafik adalah 20 dan lebar grafik adalah 7
sns.set(rc={'figure.figsize':(20,7)})

# %% [markdown]
# # 3. Mengambil Dataset Dari URL dan Menyimpan Kedalam Pandas Dataframe (1 Poin)

# %%
# Baca dataframe dari URL ini dan simpan kedalam variabel wine_df
wine_data_url = "https://raw.githubusercontent.com/Naruhodona/Calvin_Innovation_Challenge/main/datasets/winemag-data-130k-v2.csv"
# Lengkapilan kode dibawah ini
wine_df = pd.read_csv(wine_data_url,index_col=[0])
# Tampilan Dataframe
display(wine_df)
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                  NaN                NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966  Anna Lee C. Iijima                   NaN
# 129967        Paul Gregutt           @paulgwine
# 129968          Roger Voss            @vossroger
# 129969          Roger Voss            @vossroger
# 129970          Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 13 columns]

# %% [markdown]
# # Penjelasan Dataset (jangan mengubah bagian ini)

# %% [markdown]
# <p>Penjelasan dataset dapat anda lihat dari tautan berikut <a href="https://www.kaggle.com/datasets/zynicide/wine-reviews/data">Wine Review</a></p>
# <table>
#     <tr>
#         <th>Nama Kolom</th>
#         <th>Deskripsi</th>
#     </tr>
#     <tr>
#         <td>country</td>
#         <td>Negara asal anggur tersebut</td>
#     </tr>
#     <tr>
#         <td>description</td>
#         <td>Deskripsi anggur</td>
#     </tr>
#     <tr>
#         <td>designation</td>
#         <td>Kebun anggur di dalam kilang anggur tempat buah anggur yang membuat anggur itu berasal</td>
#     </tr>
#     <tr>
#         <td>points</td>
#         <td>Jumlah poin WineEnthusiast yang menilai anggur pada skala 1-100 (meskipun mereka mengatakan bahwa mereka hanya memposting ulasan untuk anggur yang skornya &gt;=80)</td>
#     </tr>
#     <tr>
#         <td>price</td>
#         <td>Biaya untuk sebotol anggur</td>
#     </tr>
#     <tr>
#         <td>province</td>
#         <td>Provinsi atau negara bagian asal anggur tersebut</td>
#     </tr>
#     <tr>
#         <td>region_1</td>
#         <td>Area penanaman anggur di suatu provinsi atau negara bagian (yaitu Napa)</td>
#     </tr>
#     <tr>
#         <td>region_2</td>
#         <td>Terkadang ada wilayah yang lebih spesifik yang ditentukan dalam area penanaman anggur (yaitu Rutherford di dalam Lembah Napa), namun nilai ini terkadang kosong</td>
#     </tr>
#     <tr>
#         <td>taster_name</td>
#         <td>Nama pemberi ulasan</td>
#     </tr>
#     <tr>
#         <td>taster_twitter_handle</td>
#         <td>Penilai anggur tersebut jika mereka memiliki akun Twitter</td>
#     </tr>
#     <tr>
#         <td>title</td>
#         <td>Judul ulasan wine, yang sering kali berisi vintage jika Anda tertarik untuk mengekstrak fitur tersebut</td>
#     </tr>
#     <tr>
#         <td>variety</td>
#         <td>Jenis buah anggur yang digunakan untuk membuat anggur (yaitu Pinot Noir)</td>
#     </tr>
#     <tr>
#         <td>winery</td>
#         <td>Pabrik anggur yang membuat anggur</td>
#     </tr>
# </table>

# %% [markdown]
# # 4. Pembersihan Data (25 Poin)

# %% [markdown]
# ## 4.1 Tampilkan Nama - Nama Kolom Dataframe (5 Poin)

# %%
# Simpan nama-nama kolom dataframe ke dalam variabel wine_df_columns
wine_df_columns = wine_df.columns

# Tampilkan
print(wine_df_columns)
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# ## 4.2 Tampilkan Shape Dari Dataframe (5 Poin)

# %%
# Simpan shape dari dataframe ke dalam variabel row,col
row,col = wine_df.shape

# Tampilkan berdasarkan print statement dibawah ini (lengkapi)
print(f"Dataset ini memiliki {row} baris dan {col} kolom")
# Out:
# Dataset ini memiliki 129971 baris dan 13 kolom

# %% [markdown]
# ## 4.3 Tampilkan Datatypes Dari Dataframe (5 Poin)

# %%
# Simpan datatypes dari dataframe wine_df ke dalam variabel wine_df_datatypes
wine_df_datatypes = wine_df.dtypes
# Tampilkan
print(wine_df_datatypes)
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %% [markdown]
# ## 4.4 Tampilkan Kolom-Kolom yang Memiliki Nilai Null Dari Dataframe (5 Poin)

# %%
# Simpan kolom-kolom wine_df yang memiliki nilai null
columns_with_null_values = wine_df.columns[wine_df.isnull().any()]

# Tampilkan
print(columns_with_null_values)
# Out:
# Index(['country', 'designation', 'price', 'province', 'region_1', 'region_2',
#        'taster_name', 'taster_twitter_handle', 'variety'],
#       dtype='object')

# %% [markdown]
# ## 4.5 Drop Row-Row yang memiliki nilai Null pada Kolom Price (5 Poin)

# %%
# Carilah jumlah rows yang memiliki nilai null pada wine_df dan simpan ke dalam variabel num_of_empty_datas
num_of_empty_datas = wine_df.isnull().sum().sum()

# Lengkapilan print statement dibawah ini
print(f"Dateset memiliki {num_of_empty_datas} baris yang kosong")

# Drop Row yang memiliki nilai null pada kolom price
wine_df.dropna(subset=['price'], inplace=True)

# Tampilkan shape dataframe setelah null rows pada kolom price di drop
print(wine_df.shape)
# Out:
# Dateset memiliki 204752 baris yang kosong
# (120975, 13)

# %% [markdown]
# # 5. Filter Data (5 Poin)

# %% [markdown]
# ## 5.1 Tampilkan Top 3 Negara Yang Memiliki Kontribusi Terbesar Dari Kolom `country` (5 Poin)

# %%
# Buatlah kode untuk menampilkan top 3 negara yang memiliki kontribusi terbesar dari kolom country dan simpan dalam variabel country_contributions
country_contributions = wine_df.groupby('country').size().sort_values(ascending = False)

# Tampilkan
print(country_contributions.head(3))
# Out:
# country
# US        54265
# France    17776
# Italy     16914
# dtype: int64

# %% [markdown]
# # 6. Visualisasi Data (20 Poin)

# %% [markdown]
# ## 6.1 Visualisasikan data dengan boxplot untuk kolom `points` dari 3 negara kontribusi terbanyak (5 Poin)

# %%
# Isilah bagian kosong dari variabel country colors ini dengan top 3 negara yang memiliki top 3 contributions
country_colors = {
    "US": 'plum',
    "France": 'orange',
    "Italy": 'g',
}

# Lengkapilah function dibawah ini (jangan ubah nama function dan parameter!)
def plot_country_vs_points_boxplot(df: pd.DataFrame, country_name: str):
    # buatlah boxplot (lengkapilah kode dibawah ini)
    sns.boxplot(x='points', y='country', data=df, palette=country_colors)
    # Tampilkan judul grafik (lengkapilah kode dibawah ini)
    plt.title(f'Distribusi Poin Anggur berdasarkan Negara {country_name}')
    # Tampilkan grafik
    plt.show()

# Buatlah 3 variabel, satu variabel untuk masing-masing negara dari 3 negara yang memiliki top 3 contributions (buat variabel dengan format <nama-negara>_df: contoh germany_df, swiss_df)
# variabel negara tertinggi rank 1
us_df = wine_df[wine_df["country"] == "US"]
# variabel negara tertinggi rank 2
france_df = wine_df[wine_df["country"] == "France"]
# variabel negara tertinggi rank 3
italy_df = wine_df[wine_df["country"] == "Italy"]

# Panggil function diatas masing-masing 1 kali untuk setiap negara
# panggil fungsi negara tertinggi rank 1
plot_country_vs_points_boxplot(us_df, "US")
# panggil fungsi negara tertinggi rank 2
plot_country_vs_points_boxplot(france_df, "France")
# panggil fungsi negara tertinggi rank 3
plot_country_vs_points_boxplot(italy_df, "Italy")

# %% [markdown]
# ## 6.2 Visualisasikan data dengan boxplot untuk kolom `price` dari 3 negara kontribusi terbanyak (5 Poin)

# %%
# Lengkapilah function dibawah ini (jangan ubah nama function dan parameter!)
def plot_country_vs_price_boxplot(df: pd.DataFrame, country_name: str):
    # buatlah boxplot (lengkapilah kode dibawah ini)
    sns.boxplot(x='price', y='country', data=df, palette=country_colors)
    # Tampilkan judul grafik (lengkapilah kode dibawah ini)
    plt.title(f'Distribusi Harga Anggur berdasarkan Negara {country_name}')
    # Tampilkan grafik
    plt.show()

# Panggil function diatas masing-masing 1 kali untuk setiap negara
# panggil fungsi negara tertinggi rank 1
plot_country_vs_price_boxplot(us_df, "US")
# panggil fungsi negara tertinggi rank 2
plot_country_vs_price_boxplot(italy_df, "Italy")
# panggil fungsi negara tertinggi rank 3
plot_country_vs_price_boxplot(france_df, "France")

# %% [markdown]
# ## 6.3 Visualisasi data dengan boxplot untuk kolom `points` dari semua negara dalam seluruh dataset (5 Poin)

# %%
# Buatlah kode boxplot vertical
sns.boxplot(x='country', y='points', data=wine_df)

# Rotasi x-axis labels 90 derajat
plt.xticks(rotation=90)

# Title grafik
plt.title('Distribusi Poin berdasarkan Negara')

# Tampilkan grafik
plt.show()

# %% [markdown]
# ## 6.4 Visualisasi data dengan boxplot untuk kolom `price` dari semua negara dalam dataset (5 Poin)

# %%
# Buatlah kode boxplot vertical
sns.boxplot(x='country', y='price', data=wine_df)

# Rotasi x-axis labels 90 derajat
plt.xticks(rotation=90)

# Title grafik
plt.title('Distribusi Price berdasarkan Negara')

# Tampilkan grafik
plt.show()

# %% [markdown]
# # 7. Statistika Deskriptif (15 Poin)

# %% [markdown]
# ## 7.1 Tampilkanlah Statistika Deskriptif Untuk Seluruh Dataframe (5 Poin)

# %%
# Tampilkanlah statistika deskriptif untuk seluruh dataframe
display(wine_df.describe())
# Out:
#               points          price
# count  120975.000000  120975.000000
# mean       88.421881      35.363389
# std         3.044508      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %% [markdown]
# ## 7.2 Tunjukkan Statistik Deskriptif untuk data kolom `points` dan `price` untuk negara 3 negara kontribusi terbanyak dan keseluruhan dataframe (10 Poin)

# %%
# lengkapilah fungsi dibawah ini (jangan mengubah nama fungsi dan parameter fungsi!)
def statistik_deskriptif(column_name: str, country_name: str = None):
    # Lengkapilah variabel title dibawah ini
    title = f"Statistik Deskriptif kolom {column_name} untuk negara {country_name}"

    # Lengkapilah if else statement dibawah ini
    # pastikan bahwa country name sama dengan nama negara top 3 kontribusi (case sensitive: contoh jika salah satu negaranya adalah negara Indonesia, maka lengkapilah kode dibawah dengan Indonesia (I kapital))
    if country_name == "US":
        selected_df = us_df
    elif country_name == "France":
        selected_df = france_df
    elif country_name == "Italy":
        selected_df = italy_df
    else:
        selected_df = wine_df
        # Lengkapilah variabel title dibawah ini
        title = f"Statistik Deskriptif kolom {column_name} untuk keseluruhan Dataframe"

    # Tampilkan judul
    print(title)
    # Lengkapilah kode dibawah ini
    rata_rata = selected_df[column_name].mean()
    min_value = selected_df[column_name].min()
    median = selected_df[column_name].median()
    q1 = selected_df[column_name].quantile(0.25)
    q3 = selected_df[column_name].quantile(0.75)
    max_value = selected_df[column_name].max()
    standar_deviasi = wine_df[column_name].std()

    # Lengkapilah print statement dibawah ini
    print(f'Rata-rata jumlah poin : {rata_rata:.2f}')
    print(f'Nilai Minimum : {min_value}')
    print(f'Quartil 1 (Q1) : {q1}')
    print(f'Median (Q2): {median}')
    print(f'Quartil 3 (Q3) : {q3}')
    print(f'Nilai Maksimum : {max_value}')
    print(f'Standar Deviasi : {standar_deviasi:.2f}')
    print()

# Panggil fungsi diatas sebanyak 8x
## 4x untuk kolom points
statistik_deskriptif("points")
statistik_deskriptif("points","US")
statistik_deskriptif("points","France")
statistik_deskriptif("points","Italy")

## 4x untuk kolom price
statistik_deskriptif("price")
statistik_deskriptif("price","US")
statistik_deskriptif("price","France")
statistik_deskriptif("price","Italy")
# Out:
# Statistik Deskriptif kolom points untuk keseluruhan Dataframe
# Rata-rata jumlah poin : 88.42
# Nilai Minimum : 80
# Quartil 1 (Q1) : 86.0
# Median (Q2): 88.0
# Quartil 3 (Q3) : 91.0
# Nilai Maksimum : 100
# Standar Deviasi : 3.04
#
# Statistik Deskriptif kolom points untuk negara US
# Rata-rata jumlah poin : 88.57
# Nilai Minimum : 80
# Quartil 1 (Q1) : 86.0
# Median (Q2): 88.0
# Quartil 3 (Q3) : 91.0
# Nilai Maksimum : 100
# Standar Deviasi : 3.04
#
# Statistik Deskriptif kolom points untuk negara France
# Rata-rata jumlah poin : 88.73
# Nilai Minimum : 80
# Quartil 1 (Q1) : 87.0
# Median (Q2): 88.0
# Quartil 3 (Q3) : 91.0
# Nilai Maksimum : 100
# Standar Deviasi : 3.04
#
# Statistik Deskriptif kolom points untuk negara Italy
# Rata-rata jumlah poin : 88.62
# Nilai Minimum : 80
# Quartil 1 (Q1) : 87.0
# Median (Q2): 88.0
# Quartil 3 (Q3) : 90.0
# Nilai Maksimum : 100
# Standar Deviasi : 3.04
#
# Statistik Deskriptif kolom price untuk keseluruhan Dataframe
# Rata-rata jumlah poin : 35.36
# Nilai Minimum : 4.0
# Quartil 1 (Q1) : 17.0
# Median (Q2): 25.0
# Quartil 3 (Q3) : 42.0
# Nilai Maksimum : 3300.0
# Standar Deviasi : 41.02
#
# Statistik Deskriptif kolom price untuk negara US
# Rata-rata jumlah poin : 36.57
# Nilai Minimum : 4.0
# Quartil 1 (Q1) : 20.0
# Median (Q2): 30.0
# Quartil 3 (Q3) : 45.0
# Nilai Maksimum : 2013.0
# Standar Deviasi : 41.02
#
# Statistik Deskriptif kolom price untuk negara France
# Rata-rata jumlah poin : 41.14
# Nilai Minimum : 5.0
# Quartil 1 (Q1) : 16.0
# Median (Q2): 25.0
# Quartil 3 (Q3) : 43.0
# Nilai Maksimum : 3300.0
# Standar Deviasi : 41.02
#
# Statistik Deskriptif kolom price untuk negara Italy
# Rata-rata jumlah poin : 39.66
# Nilai Minimum : 5.0
# Quartil 1 (Q1) : 18.0
# Median (Q2): 28.0
# Quartil 3 (Q3) : 50.0
# Nilai Maksimum : 900.0
# Standar Deviasi : 41.02

# %%
# Copy paste hasil output print pada cell sebelumnya dan masukkanlah ke variabel dibawah ini
statistika_deskriptif_string = """
Statistik Deskriptif points untuk keseluruhan Dataframe
Rata-rata jumlah poin : 88.42
Nilai Minimum : 80
Quartil 1 (Q1) : 86.0
Median (Q2): 88.0
Quartil 3 (Q3) : 91.0
Nilai Maksimum : 100
Standar Deviasi : 3.04

Statistik Deskriptif points untuk negara US
Rata-rata jumlah poin : 88.57
Nilai Minimum : 80
Quartil 1 (Q1) : 86.0
Median (Q2): 88.0
Quartil 3 (Q3) : 91.0
Nilai Maksimum : 100
Standar Deviasi : 3.04

Statistik Deskriptif points untuk negara France
Rata-rata jumlah poin : 88.73
Nilai Minimum : 80
Quartil 1 (Q1) : 87.0
Median (Q2): 88.0
Quartil 3 (Q3) : 91.0
Nilai Maksimum : 100
Standar Deviasi : 3.04

Statistik Deskriptif points untuk negara Italy
Rata-rata jumlah poin : 88.62
Nilai Minimum : 80
Quartil 1 (Q1) : 87.0
Median (Q2): 88.0
Quartil 3 (Q3) : 90.0
Nilai Maksimum : 100
Standar Deviasi : 3.04

Statistik Deskriptif price untuk keseluruhan Dataframe
Rata-rata jumlah poin : 35.36
Nilai Minimum : 4.0
Quartil 1 (Q1) : 17.0
Median (Q2): 25.0
Quartil 3 (Q3) : 42.0
Nilai Maksimum : 3300.0
Standar Deviasi : 41.02

Statistik Deskriptif price untuk negara US
Rata-rata jumlah poin : 36.57
Nilai Minimum : 4.0
Quartil 1 (Q1) : 20.0
Median (Q2): 30.0
Quartil 3 (Q3) : 45.0
Nilai Maksimum : 2013.0
Standar Deviasi : 41.02

Statistik Deskriptif price untuk negara France
Rata-rata jumlah poin : 41.14
Nilai Minimum : 5.0
Quartil 1 (Q1) : 16.0
Median (Q2): 25.0
Quartil 3 (Q3) : 43.0
Nilai Maksimum : 3300.0
Standar Deviasi : 41.02

Statistik Deskriptif price untuk negara Italy
Rata-rata jumlah poin : 39.66
Nilai Minimum : 5.0
Quartil 1 (Q1) : 18.0
Median (Q2): 28.0
Quartil 3 (Q3) : 50.0
Nilai Maksimum : 900.0
Standar Deviasi : 41.02
"""

# %% [markdown]
# # 8. Kesimpulan / Insight Statistics (34 Poin)

# %% [markdown]
# <p>Berikan Insight yang kalian dapatkan dari dataset ini berdasarkan grafik dan statistika deskriptif yang sudah kalian dapatkan dan buatlah kesimpulan, boleh dalam poin atau paragraf</p>
# <p>Insights (17 Poin): </p>
# <p>Kesimpulan (17 Poin): </p>
